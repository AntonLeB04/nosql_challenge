# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# !mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json
# Out:
# 2024-01-02T13:13:32.763-0600	connected to: mongodb://localhost/
# 2024-01-02T13:13:32.765-0600	dropping: uk_food.establishments
# 2024-01-02T13:13:33.920-0600	39779 document(s) imported successfully. 0 document(s) failed to import.

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'config', 'establishments', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review the collections in our new database
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'config', 'establishments', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': '1 The Droveway',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'FirstLight Bar & Café',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.64041272672,
#  'FHRSID': 1290215,
#  'LocalAuthorityBusinessID': 'PI/000083029',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DH',
#  'RatingDate': '2020-11-09T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594605c409439183674bcbe'),
#  'geocode': {'latitude': '51.150625', 'longitude': '1.378231'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1290215',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('6594605ee39da63662ddefab'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
pprint(establishments.find_one(new_restaurant))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594605ee39da63662ddefab'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
field = {"BusinessType": 1, "BusinessType": 1}
sort = list(establishments.find(query, field))
pprint(sort)
# Out:
# [{'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcbe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcbf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcc1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcc7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcc8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcc9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bccc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcd1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcd3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcd4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcd5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcd9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcdd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcdf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bce3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bced')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcf4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcf5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcf6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcf7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcf8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcfe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bcff')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd02')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd06')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd08')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd09')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd0a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd0f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd10')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd16')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd17')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd19')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd1b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd20')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd22')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd24')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd27')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd28')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd2a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd2b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd2c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd31')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd38')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd3a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd3b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd3e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd43')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd44')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd4b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd51')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd52')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd58')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd59')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd5a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd5b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd5d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd62')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd6a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd6b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd6d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd6e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd6f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd78')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd7a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd7f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd80')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd82')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd86')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd8c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd8d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd91')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd94')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bd9b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bda7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdb3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdb4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdb6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdb7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdbc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdc1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdc5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdce')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdd0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdda')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bddc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bddf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bde0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bde9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdf0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdf2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdf3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdf8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdfa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bdff')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be00')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be02')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be05')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be06')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be07')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be09')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be0a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be0b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be0d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be13')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be17')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be19')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be1d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be2a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be2b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be2c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be2d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be2e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be31')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be32')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be34')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be3c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be41')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be42')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be43')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be47')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be48')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be4a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be56')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be57')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be5d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be60')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be62')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be63')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be6f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be70')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be77')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be7d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be7f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be84')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be88')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be8a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be8d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be91')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be95')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be96')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674be98')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bea3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674beaf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674becc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bed9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bee2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674beeb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bef0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bef4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf05')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf0c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf0d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf1f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf20')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf32')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf34')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf36')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf38')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf48')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf59')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf5a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf5c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf62')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf64')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf6b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf6c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf72')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf76')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf78')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf7a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf7c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf7e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf90')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf91')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bf9a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfa6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfaa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfb1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfb9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfbc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfbd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfbe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfc9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfcd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfd3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfda')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfe2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfe3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfe8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bff0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bff4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bff5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bff8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bff9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bffd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674bfff')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c000')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c001')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c002')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c00a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c00d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c011')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c013')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c014')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c015')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c017')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c01b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c01e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c027')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c029')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c02a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c02d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c02e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c032')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c033')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c038')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c03b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c03d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c040')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c042')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c043')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c047')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c049')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c04b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c04e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c050')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c056')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c059')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c05c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c05f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c061')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c066')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c068')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c069')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c071')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c073')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c076')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c077')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c07a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c07c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c07d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c07f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c083')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c084')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c085')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c086')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c08a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c08c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c08d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0a1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0a4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0a6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0aa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0b2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0d1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0f3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c0f7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c114')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c116')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c117')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c11c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c11f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c124')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c128')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c129')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c12b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c131')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c134')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c138')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c13a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c13c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c13d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c13e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c13f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c141')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c142')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c148')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c14b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c14c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c151')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c153')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c154')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c156')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c158')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c15a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c15b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c15d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c15f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c160')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c161')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c164')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c167')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c16a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c16c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c176')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c177')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c178')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c179')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c17b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c17c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c180')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c183')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c184')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c18e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c191')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c193')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c194')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c196')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c19d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1a0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1a6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1cf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1d9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1e4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1ea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1ef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1f7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c1fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c200')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c201')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c202')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c209')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c20a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c20b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c20e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c210')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c212')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c217')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c218')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c219')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c21a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c21b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c21c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c221')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c222')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c223')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c224')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c225')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c227')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c228')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c229')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c22b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c22c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c22d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c22e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c231')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c232')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c234')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c236')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c238')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c23c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c23d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c243')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c244')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c245')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c247')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c24b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c24c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c250')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c253')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c257')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c258')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c25c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c25f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c261')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c269')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c26a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c26c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c279')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c284')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c28a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c291')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c294')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c295')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c297')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2a3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2a6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2d0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2d5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c2fa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c300')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c304')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c305')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c306')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c311')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c31a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c31f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c320')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c322')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c323')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c326')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c327')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c32a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c32b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c32c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c331')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c334')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c336')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c337')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c33b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c33e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c33f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c340')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c341')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c345')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c346')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c34c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c34d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c34f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c351')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c352')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c358')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c359')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c35c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c362')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c364')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c365')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c36e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c376')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c379')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c37a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c37b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c382')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c383')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c384')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c387')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c38e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c38f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c395')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c39a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c39b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3a0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3aa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3d0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3f0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3f5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3f8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c3fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c400')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c402')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c407')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c40a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c414')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c415')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c417')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c41a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c421')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605c409439183674c423')},
# ...
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555b1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555da')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555f0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555f9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367555fc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755603')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755604')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755606')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755608')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675560b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675560c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675560d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675560f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755611')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755612')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755613')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755618')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675561c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675561d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675561f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755623')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675562d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675562f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755630')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755635')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755636')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755637')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755638')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755639')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675563a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675563e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755640')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755641')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755642')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755644')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755646')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755648')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675564a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675564d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675564e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755651')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755655')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755658')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755659')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675565b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675565c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675565d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755660')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755662')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755667')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675566d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675566f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755672')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755678')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675567b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675567f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755685')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675568a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675568c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755693')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556b4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556e5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556f8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367556fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755708')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755709')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675570e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675570f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755714')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755716')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755718')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755719')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675571f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755732')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755733')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675573e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675573f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755745')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675574c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675574e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755751')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755759')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675575c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675575d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675575f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755763')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675576b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675576f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755772')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755773')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755774')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755777')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755778')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675577a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675577c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675577f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755783')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755784')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755785')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755786')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755787')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755789')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675578a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675578b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675578c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675578d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675578e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755790')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755792')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755799')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675579a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557a1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557a3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557aa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557ac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557c3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557cb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557e5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d40943918367557fc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755801')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755805')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755808')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675580a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755810')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d4094391836755811')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605d409439183675581f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('6594605ee39da63662ddefab')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_many({'BussinessType':'Restaurant/Cafe/Canteen'}, {'$set': {'BussinessType': 1}})
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
query2 = {'BusinessName' : 'Penang Flavours'}
sort2 = list(establishments.find(query2))
pprint(sort2)
# Out:
# [{'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   'Distance': 4623.972328074718,
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': True,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6594605ee39da63662ddefab'),
#   'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#   'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query3 = {'LocalAuthorityName' : 'Dover'}
sort3 = establishments.count_documents(query3)
print(sort3)
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName' : 'Dover'})
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
sort4 = establishments.count_documents(query3)
print(sort4)
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594605c409439183674bf9a'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{'$set': {"geocode.longitude" : {'$toDecimal' : '$geocode.longitude'}}}])
establishments.update_many({}, [{'$set': {"geocode.latitude" : {'$toDecimal' : '$geocode.longitude'}}}])
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594605c409439183674bf9a'),
#  'geocode': {'latitude': Decimal128('1.195625'),
#              'longitude': Decimal128('1.195625')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set': {"RateingValue" : {'$toInt' : '$RatingValue'}}}])
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RateingValue': 5,
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594605c409439183674bf9a'),
#  'geocode': {'latitude': Decimal128('1.195625'),
#              'longitude': Decimal128('1.195625')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
